# %%
# !apt-file search .efi
# Out:
# dell-recovery: /usr/lib/dell/x86_64/MokSBStateSet.efi
# efingerd: /usr/share/doc/efingerd/examples/examples-standard/.efingerd
# efitools: /usr/share/efitools/efi/HashTool.efi
# efitools: /usr/share/efitools/efi/HelloWorld.efi
# efitools: /usr/share/efitools/efi/KeyTool.efi
# efitools: /usr/share/efitools/efi/Loader.efi
# efitools: /usr/share/efitools/efi/LockDown.efi
# efitools: /usr/share/efitools/efi/ReadVars.efi
# efitools: /usr/share/efitools/efi/SetNull.efi
# efitools: /usr/share/efitools/efi/ShimReplace.efi
# efitools: /usr/share/efitools/efi/UpdateVars.efi
# fwupd: /usr/libexec/fwupd/efi/fwupdx64.efi
# fwupd-signed: /usr/libexec/fwupd/efi/fwupdx64.efi.signed
# grc: /usr/share/doc/grc/contrib/conf.efingerd
# grub-efi-amd64-bin: /usr/lib/grub/x86_64-efi/monolithic/gcdx64.efi
# grub-efi-amd64-bin: /usr/lib/grub/x86_64-efi/monolithic/grubnetx64.efi
# grub-efi-amd64-bin: /usr/lib/grub/x86_64-efi/monolithic/grubx64.efi
# ...

# %%
# !apt-file search .iso|grep iso$
# Out:
# grass-core: /usr/lib/grass78/bin/v.net.iso
# grub-rescue-pc: /usr/lib/grub-rescue/grub-rescue-cdrom.iso
# ipxe: /usr/lib/ipxe/ipxe.iso
# libbiblio-thesaurus-perl: /usr/share/doc/libbiblio-thesaurus-perl/examples/animals1.iso
# libbiblio-thesaurus-perl: /usr/share/doc/libbiblio-thesaurus-perl/examples/animals2.iso
# memtest86+: /usr/lib/memtest86+/memtest86+.iso
# minicom: /usr/share/doc/minicom/tables/mc.iso
# texlive-lang-cyrillic: /usr/share/doc/texlive-doc/fonts/cmcyr/merge.iso
# trnascan-se: /usr/share/doc/trnascan-se/examples/Example1-tRNAs.iso
# trnascan-se: /usr/share/doc/trnascan-se/examples/Example2-tRNAs.iso
# virtualbox-guest-additions-iso: /usr/share/virtualbox/VBoxGuestAdditions.iso

# %%
# !man apt-file
# Out:
# APT-FILE(1)           User Contributed Perl Documentation          APT-FILE(1)
#
# E
#        apt-file -- APT package searching utility -- command-line interface
#
# S
# n
#
# e
#
# N
# e is a command line tool for searching files in packages for the
#        APT package management system.
#
#        Some actions are required to run the search:
#
#        find
#            Alias for search.
#
#        list
#            List the contents of a package. This action is very close to the
# L command except the package does not need to be installed or
#            fetched.
#
# t action interprets its pattern as if
# g was specified.
#
#        list-indices
#            List the known Content indices and their status in a human readable
# I option (when
#            enabled and after fetching the indices).  The output is subject to
#            change without notice and is therefore unsuited for script usage /
#            automation.
#
# -
# p (search for options starting with
# ...

# %%
ls
# Out:
# 1.ipy.sys.path*  2.pip.log*      PowerShell0.ipynb*       pandas-1.ipynb*
# 1.pip.log*       2.py.sys.path*  bashPowerShell0.ipynb*   poku*
# 1.py.sys.path*   2225.bashrc*    f3-of-f234-groupby.csv*  s1*
# 11*              3.pip.log*      f3-of-f234.csv*          wsl/

# %%
# !ls
# Out:
# 1.ipy.sys.path	2.pip.log      PowerShell0.ipynb       pandas-1.ipynb
# 1.pip.log	2.py.sys.path  bashPowerShell0.ipynb   poku
# 1.py.sys.path	2225.bashrc    f3-of-f234-groupby.csv  s1
# 11		3.pip.log      f3-of-f234.csv	       wsl

# %%
5*5
# Out:
# 25

# %%
# !df -m
# Out:
# Filesystem     1M-blocks   Used Available Use% Mounted on
# /dev/sdd          257007   5055    238829   3% /
# tmpfs               3094    365      2729  12% /mnt/wsl
# /dev/sdc          257007   8975    234909   4% /mnt/wsl/docker-desktop-data/isocache
# none                3094      1      3094   1% /mnt/wsl/docker-desktop/shared-sockets/host-services
# /dev/sdb          257007    123    243760   1% /mnt/wsl/docker-desktop/docker-desktop-proxy
# /dev/loop0           334    334         0 100% /mnt/wsl/docker-desktop/cli-tools
# tools             151921 135776     16146  90% /init
# none                3092      0      3092   0% /dev
# none                3094      1      3094   1% /run
# none                3094      0      3094   0% /run/lock
# none                3094      0      3094   0% /run/shm
# none                3094      0      3094   0% /run/user
# tmpfs               3094      0      3094   0% /sys/fs/cgroup
# ...

# %%
ls
# Out:
# <div>
#     <div id='dotnet-interactive-this-cell-23132.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
#         The below script needs to be able to find the current output cell; this is an easy method to get it.
#     </div>
#     <script type='text/javascript'>
# async function probeAddresses(probingAddresses) {
#     function timeout(ms, promise) {
#         return new Promise(function (resolve, reject) {
#             setTimeout(function () {
#                 reject(new Error('timeout'))
#             }, ms)
#             promise.then(resolve, reject)
#         })
#     }
#
#     if (Array.isArray(probingAddresses)) {
#         for (let i = 0; i < probingAddresses.length; i++) {
#
#             let rootUrl = probingAddresses[i];
#
#             if (!rootUrl.endsWith('/')) {
#                 rootUrl = `${rootUrl}/`;
#             }
#
#             try {
#                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
# ...
